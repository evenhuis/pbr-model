# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
df =pd.read_csv("mod10_input_test_simple.txt.csv",index_col='Time')

# %%
plt.plot(df['PM'])
plt.plot(df['P_HCO3'])
