# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_py = pd.read_csv("mod10_input_DE_comp.txt.csv",index_col='Time')
df_py.head()
# Out:
#                   O2          DIC      TA     C_pbr     C_tot    1        pH  \
# Time
# 0.600000  230.000000  1200.000000  1700.0  1.000000  0.000000  0.0  8.497015
# 0.602849  221.056310  1206.203737  1700.0 -0.367612 -1.367612  0.0  8.487398
# 0.605698  215.988172  1212.372716  1700.0 -1.735223 -2.735223  0.0  8.477812
# 0.608548  213.116200  1218.506044  1700.0 -3.102835 -4.102835  0.0  8.468256
# 0.611397  211.488734  1224.602815  1700.0 -4.470446 -5.470446  0.0  8.458729
#
#                CO2        HCO3         CO3             PM  P_CO2  P_HCO3  \
# Time
# 0.600000  2.031129  899.484584  298.484288  5.941588e-313    0.0     0.0
# 0.602849  2.098695  909.052213  295.052829  5.941588e-313    0.0     0.0
# 0.605698  2.168002  918.571165  291.633549  5.941588e-313    0.0     0.0
# 0.608548  2.239079  928.039670  288.227295  5.941588e-313    0.0     0.0
# 0.611397  2.311958  937.455945  284.834912  5.941588e-313    0.0     0.0
#
#           P_CO3      R
# Time
# 0.600000    0.0 -480.0
# 0.602849    0.0 -480.0
# 0.605698    0.0 -480.0
# 0.608548    0.0 -480.0
# 0.611397    0.0 -480.0

# %%
df_lib=pd.read_table("../LIB_comp_trace.txt",sep=",",index_col='time')
df_lib.head()
# Out:
#                 O_2      p_H     alk          DIC       CO2         HCO3  \
# time
# 0.61304  230.000000  8.50000  1700.0  1200.000000  3.000000  1000.000000
# 0.61373  226.206185  8.50000  1700.0  1201.071649  3.000000  1000.000000
# 0.61442  223.175587  8.66442  1700.0  1202.457058  1.191022   953.862296
# 0.61511  221.380734  8.66442  1700.0  1204.065999  1.191022   953.862296
# 0.61580  219.816823  8.66442  1700.0  1205.674940  1.191022   953.862296
#
#                 CO3
# time
# 0.61304  300.000000
# 0.61373  300.000000
# 0.61442  246.657712
# 0.61511  246.657712
# 0.61580  246.657712

# %%
fig,axs = plt.subplots(3,1)
ax = axs[0]
ax.plot(df_lib['O_2'],label='libbi')
ax.plot(df_py['O2'],label='python')

ax=axs[1]
ax.plot(df_lib['p_H'],label='libbi')
ax.plot(df_py['pH'],label='python')

ax=axs[2]
ax.plot(df_lib['HCO3'],label='libbi')
ax.plot(df_py['HCO3'],label='python')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
